# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras import callbacks
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
"""
Parameters
"""
epochs = 100
img_width, img_height =300,300
classes_num = 5
batch_size=32
arsitektur = 'Leafnet Elseveir'
#lr = 0.0004

# %%
model = Sequential()
model.add(Convolution2D(32, 9, 9, border_mode ="same", input_shape=(img_width, img_height, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Convolution2D(64, 5, 5, border_mode ="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Convolution2D(128, 3, 3, border_mode ="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Convolution2D(256, 3, 3, border_mode ="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Convolution2D(512, 3, 3, border_mode ="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Convolution2D(768, 3, 3, border_mode ="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(2048))
model.add(Activation("relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

model.add(Dense(2048))
model.add(Activation("relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

model.add(Dense(classes_num, activation='softmax'))

model.summary()


architecure_dir = os.path.join('/content/gdrive/My Drive/Colab Notebooks/LeafClassification/',arsitektur)
if not os.path.exists(architecure_dir):
  os.mkdir(architecure_dir)
# Save the model architecture
with open(os.path.join(architecure_dir,'architecture.json'), 'w') as f:
    f.write(model.to_json())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (9, 9), input_shape=(300, 300,..., padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (5, 5), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), padding="same")`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(768, (3, 3), padding="same")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 300, 300, 32)      7808
# _________________________________________________________________
# activation_1 (Activation)    (None, 300, 300, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 150, 150, 32)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 150, 150, 32)      128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 150, 150, 64)      51264
# _________________________________________________________________
# activation_2 (Activation)    (None, 150, 150, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 75, 75, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 75, 75, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 256)       295168
# _________________________________________________________________
# activation_4 (Activation)    (None, 37, 37, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 18, 18, 256)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 18, 18, 256)       1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 18, 18, 512)       1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 18, 18, 512)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 9, 9, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 9, 9, 512)         2048
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 9, 9, 768)         3539712
# _________________________________________________________________
# activation_6 (Activation)    (None, 9, 9, 768)         0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 768)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 768)         3072
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12288)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              25167872
# _________________________________________________________________
# activation_7 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# activation_8 (Activation)    (None, 2048)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 10245
# =================================================================
# Total params: 34,545,861
# Trainable params: 34,534,149
# Non-trainable params: 11,712
# _________________________________________________________________

# %%
DATA_DIR = '/content/gdrive/My Drive/CITS Color'

train_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2) # set validation split

train_generator = train_datagen.flow_from_directory(
    DATA_DIR,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training') # set as training data

validation_generator = train_datagen.flow_from_directory(
    DATA_DIR, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation') # set as validation data
# Out:
# Found 1079 images belonging to 5 classes.
# Found 268 images belonging to 5 classes.

# %%
from keras.models import model_from_json
with open(os.path.join(architecure_dir,'architecture.json'), 'r') as f:
    model = model_from_json(f.read())

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
"""
Tensorboard log
"""


log_dir = os.path.join(architecure_dir, 'tf-log')
tb_cb = callbacks.TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=True)
cbks = [tb_cb]

"""model.fit_generator(
    train_generator,
    samples_per_epoch=samples_per_epoch,
    epochs=epochs,
    validation_data=validation_generator,
    callbacks=cbks,
    validation_steps=validation_steps)"""

model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    callbacks=cbks,
    epochs = epochs,
    shuffle = True)

#model.fit_generator(datagen.flow(x_train, y_train, batch_size=32), steps_per_epoch=len(x_train) / 32, epochs=epochs)

target_dir =os.path.join(architecure_dir, 'models')
if not os.path.exists(target_dir):
  os.mkdir(target_dir)
  
model.save(os.path.join(target_dir, 'model.h5'))
model.save_weights(os.path.join(target_dir, 'weights.h5'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 33/33 [==============================] - 37s 1s/step - loss: 1.1324 - acc: 0.6506 - val_loss: 10.7700 - val_acc: 0.2539
# Epoch 2/100
# 33/33 [==============================] - 32s 979ms/step - loss: 0.8265 - acc: 0.7393 - val_loss: 5.6904 - val_acc: 0.3814
# Epoch 3/100
# 33/33 [==============================] - 31s 930ms/step - loss: 0.7784 - acc: 0.7602 - val_loss: 10.8161 - val_acc: 0.2203
# Epoch 4/100
# 33/33 [==============================] - 31s 952ms/step - loss: 0.5630 - acc: 0.8027 - val_loss: 2.2140 - val_acc: 0.5466
# Epoch 5/100
# 33/33 [==============================] - 31s 931ms/step - loss: 0.5872 - acc: 0.7925 - val_loss: 6.5565 - val_acc: 0.3856
# Epoch 6/100
# 33/33 [==============================] - 31s 934ms/step - loss: 0.6043 - acc: 0.7859 - val_loss: 4.6423 - val_acc: 0.4831
# Epoch 7/100
# 33/33 [==============================] - 31s 936ms/step - loss: 0.4041 - acc: 0.8580 - val_loss: 3.1671 - val_acc: 0.6144
# Epoch 8/100
# 33/33 [==============================] - 31s 935ms/step - loss: 0.4973 - acc: 0.8139 - val_loss: 1.4434 - val_acc: 0.7203
# Epoch 9/100
# 33/33 [==============================] - 31s 936ms/step - loss: 0.4985 - acc: 0.8395 - val_loss: 12.9672 - val_acc: 0.1949
# Epoch 10/100
# 33/33 [==============================] - 31s 942ms/step - loss: 0.3352 - acc: 0.8714 - val_loss: 12.9700 - val_acc: 0.1953
# Epoch 11/100
# 33/33 [==============================] - 31s 937ms/step - loss: 0.3739 - acc: 0.8724 - val_loss: 3.1471 - val_acc: 0.4195
# Epoch 12/100
# 33/33 [==============================] - 31s 935ms/step - loss: 0.3907 - acc: 0.8549 - val_loss: 2.1689 - val_acc: 0.6017
# Epoch 13/100
# 33/33 [==============================] - 31s 942ms/step - loss: 0.4367 - acc: 0.8449 - val_loss: 12.4095 - val_acc: 0.2034
# Epoch 14/100
# 33/33 [==============================] - 31s 940ms/step - loss: 0.3698 - acc: 0.8577 - val_loss: 1.0037 - val_acc: 0.6907
# Epoch 15/100
# 33/33 [==============================] - 31s 933ms/step - loss: 0.2866 - acc: 0.8960 - val_loss: 3.7214 - val_acc: 0.3475
# Epoch 16/100
# 33/33 [==============================] - 31s 937ms/step - loss: 0.3401 - acc: 0.8746 - val_loss: 2.4230 - val_acc: 0.5381
# Epoch 17/100
# 33/33 [==============================] - 31s 936ms/step - loss: 0.3472 - acc: 0.8748 - val_loss: 1.7897 - val_acc: 0.4915
# Epoch 18/100
# 33/33 [==============================] - 31s 937ms/step - loss: 0.4666 - acc: 0.8451 - val_loss: 4.6967 - val_acc: 0.4449
# Epoch 19/100
# 33/33 [==============================] - 31s 937ms/step - loss: 0.3573 - acc: 0.8681 - val_loss: 1.1201 - val_acc: 0.6406
# Epoch 20/100
# 33/33 [==============================] - 31s 938ms/step - loss: 0.2669 - acc: 0.8888 - val_loss: 3.5424 - val_acc: 0.5085
# Epoch 21/100
# 33/33 [==============================] - 31s 941ms/step - loss: 0.2977 - acc: 0.8879 - val_loss: 1.7836 - val_acc: 0.7076
# Epoch 22/100
# 33/33 [==============================] - 31s 941ms/step - loss: 0.2764 - acc: 0.8998 - val_loss: 0.3853 - val_acc: 0.9068
# Epoch 23/100
# 33/33 [==============================] - 31s 938ms/step - loss: 0.2716 - acc: 0.8831 - val_loss: 0.4228 - val_acc: 0.9153
# Epoch 24/100
# 33/33 [==============================] - 31s 939ms/step - loss: 0.2936 - acc: 0.9053 - val_loss: 0.3880 - val_acc: 0.8898
# Epoch 25/100
# 33/33 [==============================] - 31s 941ms/step - loss: 0.2865 - acc: 0.8954 - val_loss: 0.4436 - val_acc: 0.8390
# Epoch 26/100
# 33/33 [==============================] - 31s 943ms/step - loss: 0.2368 - acc: 0.9146 - val_loss: 4.6150 - val_acc: 0.2288
# Epoch 27/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.2279 - acc: 0.9115 - val_loss: 5.0639 - val_acc: 0.2161
# Epoch 28/100
# 33/33 [==============================] - 31s 948ms/step - loss: 0.1943 - acc: 0.9292 - val_loss: 0.3439 - val_acc: 0.8633
# Epoch 29/100
# 33/33 [==============================] - 31s 942ms/step - loss: 0.2118 - acc: 0.9163 - val_loss: 3.7326 - val_acc: 0.4322
# Epoch 30/100
# 33/33 [==============================] - 31s 943ms/step - loss: 0.2167 - acc: 0.9140 - val_loss: 3.0278 - val_acc: 0.4619
# Epoch 31/100
# 33/33 [==============================] - 31s 952ms/step - loss: 0.2979 - acc: 0.8926 - val_loss: 0.6425 - val_acc: 0.8051
# Epoch 32/100
# 33/33 [==============================] - 31s 949ms/step - loss: 0.3127 - acc: 0.8775 - val_loss: 6.8742 - val_acc: 0.4237
# Epoch 33/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.2227 - acc: 0.9134 - val_loss: 0.9866 - val_acc: 0.7373
# Epoch 34/100
# 33/33 [==============================] - 31s 947ms/step - loss: 0.1935 - acc: 0.9220 - val_loss: 0.5780 - val_acc: 0.8178
# Epoch 35/100
# 33/33 [==============================] - 32s 956ms/step - loss: 0.2053 - acc: 0.9223 - val_loss: 0.5567 - val_acc: 0.8008
# Epoch 36/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.2635 - acc: 0.9037 - val_loss: 3.1020 - val_acc: 0.5212
# Epoch 37/100
# 33/33 [==============================] - 31s 948ms/step - loss: 0.1910 - acc: 0.9323 - val_loss: 2.9571 - val_acc: 0.5000
# Epoch 38/100
# 33/33 [==============================] - 31s 942ms/step - loss: 0.1818 - acc: 0.9305 - val_loss: 0.7356 - val_acc: 0.7627
# Epoch 39/100
# 33/33 [==============================] - 31s 947ms/step - loss: 0.2153 - acc: 0.9260 - val_loss: 5.0555 - val_acc: 0.4958
# Epoch 40/100
# 33/33 [==============================] - 32s 955ms/step - loss: 0.2575 - acc: 0.8985 - val_loss: 2.5252 - val_acc: 0.4534
# Epoch 41/100
# 33/33 [==============================] - 31s 947ms/step - loss: 0.2072 - acc: 0.9222 - val_loss: 3.1038 - val_acc: 0.4195
# Epoch 42/100
# 33/33 [==============================] - 31s 943ms/step - loss: 0.2134 - acc: 0.9273 - val_loss: 0.6613 - val_acc: 0.7754
# Epoch 43/100
# 33/33 [==============================] - 31s 944ms/step - loss: 0.2023 - acc: 0.9229 - val_loss: 0.3005 - val_acc: 0.8771
# Epoch 44/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.2105 - acc: 0.9290 - val_loss: 1.3758 - val_acc: 0.6483
# Epoch 45/100
# 33/33 [==============================] - 31s 951ms/step - loss: 0.3667 - acc: 0.8759 - val_loss: 12.6538 - val_acc: 0.2076
# Epoch 46/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.3656 - acc: 0.8828 - val_loss: 6.0697 - val_acc: 0.4883
# Epoch 47/100
# 33/33 [==============================] - 31s 944ms/step - loss: 0.2558 - acc: 0.9112 - val_loss: 1.9907 - val_acc: 0.6525
# Epoch 48/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.2741 - acc: 0.8993 - val_loss: 2.9782 - val_acc: 0.5636
# Epoch 49/100
# 33/33 [==============================] - 31s 952ms/step - loss: 0.2661 - acc: 0.9095 - val_loss: 5.5994 - val_acc: 0.4661
# Epoch 50/100
# 33/33 [==============================] - 31s 944ms/step - loss: 0.2156 - acc: 0.9288 - val_loss: 1.4424 - val_acc: 0.7331
# Epoch 51/100
# 33/33 [==============================] - 31s 949ms/step - loss: 0.2028 - acc: 0.9286 - val_loss: 1.9452 - val_acc: 0.4873
# Epoch 52/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.1527 - acc: 0.9453 - val_loss: 1.6527 - val_acc: 0.6949
# Epoch 53/100
# 33/33 [==============================] - 31s 949ms/step - loss: 0.1573 - acc: 0.9485 - val_loss: 1.9852 - val_acc: 0.5932
# Epoch 54/100
# 33/33 [==============================] - 31s 941ms/step - loss: 0.1537 - acc: 0.9421 - val_loss: 0.4308 - val_acc: 0.8263
# Epoch 55/100
# 33/33 [==============================] - 31s 943ms/step - loss: 0.1746 - acc: 0.9438 - val_loss: 0.1808 - val_acc: 0.9492
# Epoch 56/100
# 33/33 [==============================] - 31s 947ms/step - loss: 0.1590 - acc: 0.9424 - val_loss: 0.8016 - val_acc: 0.7373
# Epoch 57/100
# 33/33 [==============================] - 31s 951ms/step - loss: 0.1328 - acc: 0.9489 - val_loss: 0.8695 - val_acc: 0.7415
# Epoch 58/100
# 33/33 [==============================] - 31s 951ms/step - loss: 0.1438 - acc: 0.9494 - val_loss: 0.1993 - val_acc: 0.9280
# Epoch 59/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.1229 - acc: 0.9485 - val_loss: 0.3285 - val_acc: 0.8644
# Epoch 60/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.1742 - acc: 0.9377 - val_loss: 0.3861 - val_acc: 0.8686
# Epoch 61/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.1025 - acc: 0.9612 - val_loss: 0.0882 - val_acc: 0.9576
# Epoch 62/100
# 33/33 [==============================] - 31s 950ms/step - loss: 0.0894 - acc: 0.9659 - val_loss: 0.5183 - val_acc: 0.8432
# Epoch 63/100
# 33/33 [==============================] - 31s 944ms/step - loss: 0.1046 - acc: 0.9633 - val_loss: 1.6999 - val_acc: 0.5720
# Epoch 64/100
# 33/33 [==============================] - 31s 950ms/step - loss: 0.1841 - acc: 0.9415 - val_loss: 1.9990 - val_acc: 0.5977
# Epoch 65/100
# 33/33 [==============================] - 31s 943ms/step - loss: 0.2073 - acc: 0.9210 - val_loss: 0.6799 - val_acc: 0.8008
# Epoch 66/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.1423 - acc: 0.9517 - val_loss: 1.0207 - val_acc: 0.6907
# Epoch 67/100
# 33/33 [==============================] - 31s 953ms/step - loss: 0.1433 - acc: 0.9545 - val_loss: 1.1248 - val_acc: 0.7076
# Epoch 68/100
# 33/33 [==============================] - 31s 942ms/step - loss: 0.0975 - acc: 0.9671 - val_loss: 0.3396 - val_acc: 0.8475
# Epoch 69/100
# 33/33 [==============================] - 31s 950ms/step - loss: 0.1260 - acc: 0.9527 - val_loss: 2.3487 - val_acc: 0.6059
# Epoch 70/100
# 33/33 [==============================] - 31s 940ms/step - loss: 0.0967 - acc: 0.9687 - val_loss: 0.3571 - val_acc: 0.9068
# Epoch 71/100
# 33/33 [==============================] - 31s 944ms/step - loss: 0.0942 - acc: 0.9608 - val_loss: 2.2371 - val_acc: 0.5678
# Epoch 72/100
# 33/33 [==============================] - 31s 943ms/step - loss: 0.0894 - acc: 0.9706 - val_loss: 0.5486 - val_acc: 0.8559
# Epoch 73/100
# 33/33 [==============================] - 31s 950ms/step - loss: 0.1219 - acc: 0.9633 - val_loss: 1.4617 - val_acc: 0.6250
# Epoch 74/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.0835 - acc: 0.9665 - val_loss: 4.1302 - val_acc: 0.3644
# Epoch 75/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.1206 - acc: 0.9578 - val_loss: 0.3383 - val_acc: 0.9195
# Epoch 76/100
# 33/33 [==============================] - 32s 959ms/step - loss: 0.0872 - acc: 0.9684 - val_loss: 0.2134 - val_acc: 0.9407
# Epoch 77/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.1150 - acc: 0.9589 - val_loss: 0.4625 - val_acc: 0.8559
# Epoch 78/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.1939 - acc: 0.9311 - val_loss: 0.4194 - val_acc: 0.9110
# Epoch 79/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.1330 - acc: 0.9523 - val_loss: 0.9495 - val_acc: 0.6822
# Epoch 80/100
# 33/33 [==============================] - 31s 948ms/step - loss: 0.0996 - acc: 0.9561 - val_loss: 6.4098 - val_acc: 0.4449
# Epoch 81/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.0993 - acc: 0.9684 - val_loss: 1.6471 - val_acc: 0.6568
# Epoch 82/100
# 33/33 [==============================] - 31s 954ms/step - loss: 0.0994 - acc: 0.9589 - val_loss: 0.6037 - val_acc: 0.8555
# Epoch 83/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.0575 - acc: 0.9725 - val_loss: 0.9281 - val_acc: 0.7669
# Epoch 84/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.1030 - acc: 0.9640 - val_loss: 3.8432 - val_acc: 0.6229
# Epoch 85/100
# 33/33 [==============================] - 31s 952ms/step - loss: 0.1280 - acc: 0.9650 - val_loss: 0.9783 - val_acc: 0.8729
# Epoch 86/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.0871 - acc: 0.9678 - val_loss: 1.5198 - val_acc: 0.7500
# Epoch 87/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.0769 - acc: 0.9706 - val_loss: 2.3863 - val_acc: 0.6949
# Epoch 88/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.1139 - acc: 0.9661 - val_loss: 0.2574 - val_acc: 0.9449
# Epoch 89/100
# 33/33 [==============================] - 31s 942ms/step - loss: 0.1662 - acc: 0.9507 - val_loss: 8.8753 - val_acc: 0.4407
# Epoch 90/100
# 33/33 [==============================] - 31s 952ms/step - loss: 0.1131 - acc: 0.9636 - val_loss: 2.5426 - val_acc: 0.6398
# Epoch 91/100
# 33/33 [==============================] - 32s 955ms/step - loss: 0.0832 - acc: 0.9697 - val_loss: 1.7421 - val_acc: 0.7852
# Epoch 92/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.0921 - acc: 0.9674 - val_loss: 0.2252 - val_acc: 0.9534
# Epoch 93/100
# 33/33 [==============================] - 31s 947ms/step - loss: 0.1008 - acc: 0.9678 - val_loss: 0.9355 - val_acc: 0.7585
# Epoch 94/100
# 33/33 [==============================] - 32s 956ms/step - loss: 0.1056 - acc: 0.9627 - val_loss: 0.2736 - val_acc: 0.9110
# Epoch 95/100
# 33/33 [==============================] - 31s 946ms/step - loss: 0.0968 - acc: 0.9671 - val_loss: 0.7593 - val_acc: 0.8008
# Epoch 96/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.0858 - acc: 0.9725 - val_loss: 0.2735 - val_acc: 0.9237
# Epoch 97/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.0749 - acc: 0.9697 - val_loss: 2.8542 - val_acc: 0.6186
# Epoch 98/100
# 33/33 [==============================] - 31s 942ms/step - loss: 0.0998 - acc: 0.9728 - val_loss: 0.8566 - val_acc: 0.7839
# Epoch 99/100
# 33/33 [==============================] - 31s 939ms/step - loss: 0.0990 - acc: 0.9703 - val_loss: 0.8812 - val_acc: 0.7458
# Epoch 100/100
# 33/33 [==============================] - 31s 945ms/step - loss: 0.0928 - acc: 0.9690 - val_loss: 1.1867 - val_acc: 0.7422
